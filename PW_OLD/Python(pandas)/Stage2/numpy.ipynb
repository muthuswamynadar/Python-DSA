# %% [markdown]
# # Numpy operations

# %%
import numpy as np

# %%
a=np.array([1,2,3,4])
b=np.arange(5)
c=np.linspace(0,1,5)

# %%
c
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  ])

# %%
a=np.array([[1,2,3],[4,6,7]])
print(a[0][1])
a=a.reshape(3,2)
# Out:
# 2

# %%
print(a)
# Out:
# [[1 2]
#  [3 4]
#  [6 7]]

# %%
# np.mean(a)
print(np.std(a))
print(np.sum(a))
print(np.dot(a,a))
# Out:
# 2.1147629234082532
# 23
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 4
#       2 print(np.std(a))
#       3 print(np.sum(a))
# ----> 4 print(np.dot(a,a))
#
# ValueError: shapes (3,2) and (3,2) not aligned: 2 (dim 1) != 3 (dim 0)

# %%
import pandas as pd

# %%
df=pd.read_csv('sales_data.csv')

# %%
df.head()
# Out:
#          date region product   sales  profit
# 0  2024-01-01  North      TV  1000.0     200
# 1  2024-01-02  South  Laptop  1500.0     300
# 2  2024-01-03   East  Mobile   800.0     150
# 3  2024-01-04   West  Tablet     NaN     120
# 4  2024-01-05  North  Mobile  1200.0     250

# %%
df.tail()
# Out:
#          date region product   sales  profit
# 1  2024-01-02  South  Laptop  1500.0     300
# 2  2024-01-03   East  Mobile   800.0     150
# 3  2024-01-04   West  Tablet     NaN     120
# 4  2024-01-05  North  Mobile  1200.0     250
# 5  2024-01-06  South      TV     NaN     180

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   date     6 non-null      object
#  1   region   6 non-null      object
#  2   product  6 non-null      object
#  3   sales    4 non-null      float64
#  4   profit   6 non-null      int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 372.0+ bytes

# %%
#groupimg
region_sales=df.groupby('region')['sales'].sum()
print(region_sales)
# Out:
# region
# East      800.0
# North    2200.0
# South    1500.0
# West        0.0
# Name: sales, dtype: float64

# %%
productsales=df.groupby('product')['sales'].sum()
print(productsales)
# Out:
# product
# Laptop    1500.0
# Mobile    2000.0
# TV        1000.0
# Tablet       0.0
# Name: sales, dtype: float64

# %%
df.head()
# Out:
#          date region product   sales  profit
# 0  2024-01-01  North      TV  1000.0     200
# 1  2024-01-02  South  Laptop  1500.0     300
# 2  2024-01-03   East  Mobile   800.0     150
# 3  2024-01-04   West  Tablet     NaN     120
# 4  2024-01-05  North  Mobile  1200.0     250

# %%
df.isnull()
# Out:
#     date  region  product  sales  profit
# 0  False   False    False  False   False
# 1  False   False    False  False   False
# 2  False   False    False  False   False
# 3  False   False    False   True   False
# 4  False   False    False  False   False
# 5  False   False    False   True   False

# %%
df.fillna(0,inplace=True)

# %%
df
# Out:
#          date region product   sales  profit
# 0  2024-01-01  North      TV  1000.0     200
# 1  2024-01-02  South  Laptop  1500.0     300
# 2  2024-01-03   East  Mobile   800.0     150
# 3  2024-01-04   West  Tablet     0.0     120
# 4  2024-01-05  North  Mobile  1200.0     250
# 5  2024-01-06  South      TV     0.0     180

# %%
df.dropna(inplace=True)

# %%
emp_df=pd.read_csv('employee_data.csv')
sal_df=pd.read_csv('sales_data.csv')
emp_df
# Out:
#    ID     Name Department   Salary    JoinDate
# 0   1    Alice         HR  50000.0  2022-01-10
# 1   2      Bob    Finance  60000.0  2023-03-15
# 2   3  Charlie         IT  55000.0  2021-07-20
# 3   4    David  Marketing      NaN  2022-11-05
# 4   5      Eva    Finance  58000.0  2020-05-30

# %%
meger_df=pd.merge(emp_df,sal_df,on='ID',how='left')
print(meger_df)
# Out:
#    ID     Name Department   Salary    JoinDate        date region product  \
# 0   1    Alice         HR  50000.0  2022-01-10  2024-01-01  North      TV
# 1   2      Bob    Finance  60000.0  2023-03-15  2024-01-02  South  Laptop
# 2   3  Charlie         IT  55000.0  2021-07-20  2024-01-03   East  Mobile
# 3   4    David  Marketing      NaN  2022-11-05  2024-01-04   West  Tablet
# 4   5      Eva    Finance  58000.0  2020-05-30  2024-01-05  North  Mobile
#
#     sales  profit
# 0  1000.0     200
# 1  1500.0     300
# 2   800.0     150
# 3     NaN     120
# 4  1200.0     250

# %%
sal_df
# Out:
#    ID        date region product   sales  profit
# 0   1  2024-01-01  North      TV  1000.0     200
# 1   2  2024-01-02  South  Laptop  1500.0     300
# 2   3  2024-01-03   East  Mobile   800.0     150
# 3   4  2024-01-04   West  Tablet     NaN     120
# 4   5  2024-01-05  North  Mobile  1200.0     250
# 5   6  2024-01-06  South      TV     NaN     180
