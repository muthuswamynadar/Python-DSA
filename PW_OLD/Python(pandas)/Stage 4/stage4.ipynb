# %%
import numpy as np
import pandas as pd
dataz = {
    'Order ID': [1001, 1002, 1003, 1004, 1005],
    'Region': ['East', 'West', 'East', 'South', 'West'],
    'Category': ['Furniture', 'Technology', 'Office Supplies', 'Furniture', 'Technology'],
    'Sales': [250.0, 1300.5, 85.9, 300.4, 980.2],
    'Profit': [20.5, 200.3, 5.1, 45.6, 150.2],
    'Discount': [0.1, 0.2, 0.0, 0.1, 0.3]
}

# %%
df = pd.DataFrame(dataz)

# %%
df
# Out:
#    Order ID Region         Category   Sales  Profit  Discount
# 0      1001   East        Furniture   250.0    20.5       0.1
# 1      1002   West       Technology  1300.5   200.3       0.2
# 2      1003   East  Office Supplies    85.9     5.1       0.0
# 3      1004  South        Furniture   300.4    45.6       0.1
# 4      1005   West       Technology   980.2   150.2       0.3

# %%
df.describe()
# Out:
#           Order ID        Sales      Profit  Discount
# count     5.000000     5.000000    5.000000  5.000000
# mean   1003.000000   583.400000   84.340000  0.140000
# std       1.581139   526.885533   86.080735  0.114018
# min    1001.000000    85.900000    5.100000  0.000000
# 25%    1002.000000   250.000000   20.500000  0.100000
# 50%    1003.000000   300.400000   45.600000  0.100000
# 75%    1004.000000   980.200000  150.200000  0.200000
# max    1005.000000  1300.500000  200.300000  0.300000

# %%
df['Sales'].value_counts().plot()
# Out:
# <Axes: xlabel='Sales'>

# %%
import seaborn as sns
sns.scatterplot(x='Sales', y='Profit', data=df)
# Out:
# <Axes: xlabel='Sales', ylabel='Profit'>

# %%
sns.boxplot(df['Sales'])  # Detecting outliers
sns.histplot(df['Sales'], bins=30, kde=True)  # Distribution
# Out:
# <Axes: xlabel='Sales', ylabel='Sales'>

# %%
corr = df.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap='coolwarm')
# Out:
# <Axes: >
