# %% [markdown]
# # Stage 1

# %%
x=10
y=20
name="swamy"
isvalid=True
print (x)
# Out:
# 10

# %%
print(x+5)
# Out:
# 15

# %%
print(x+y)
# Out:
# 30

# %%
#control flow
x=4
if x>5:
    print("hello")
elif x==5:
    print("you are right")
else:
    print("less than 5")
# Out:
# less than 5

# %%
m=10
if m>11:
    print('Mello')
else:
    print('Lesser thant its')
# Out:
# Lesser thant its

# %%
for i in range(3):
    print("Loop : ",i)
# Out:
# Loop :  0
# Loop :  1
# Loop :  2

# %%
def read(name):
    return f"Hello,{name}"

read('swamy')
# Out:
# 'Hello,swamy'

# %%
mylist=[1,2,3]
mytuple=(4,5,6)
mydict={'a':1,'b':2}
myset={1,2,3,4}
