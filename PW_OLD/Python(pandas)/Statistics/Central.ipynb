# %%
#  Calculatiing the mean
import numpy as np
age=[10,20,30,40,22,55,77,99]
np.sum(age)

np.mean(age)

print(np.mean(age))
# Out:
# 44.125
# 44.125

# %%
# calculating the median
from scipy import stats
nos=[10,20,30,50,60,70,20]
np.median(nos)
# Out:
# np.float64(30.0)
