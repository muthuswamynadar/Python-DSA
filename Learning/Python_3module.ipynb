# %%
# data structure is way of organising and starting the data

# %%
# data structure can be string list set tuples dictionary array

# %% [markdown]
# # Using the List

# %%
num=[1,2,3,5]

# %%
num
# Out:
# [1, 2, 3, 5]

# %%
type(num)
# Out:
# list

# %%
num[0]
# Out:
# 1

# %%
num[3]
# Out:
# 5

# %%
a=[1,3,"Swamy","muthu","money",True,False,3+7j]

# %%
a.append("swamz")

# %%
a
# Out:
# [1, 'Swamy', 'muthu', 'money', True, False, (3+7j), 'swamz']

# %%
tuples=(2,3,4,6,7,98)
