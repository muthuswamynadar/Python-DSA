# %%
# DP Write a code to create a string with your name and print it
swamy="Muthuswamy"
print(swamy)
# Out:
# Muthuswamy

# %%
# /P Write a code to find the length of the string "Hello World
str2="Hello World"
print("the lenght of word is "+len(str2))
# Out:
# 11

# %%
# Write a code to slice the first 3 characters from 
# the string "Python Programming"P

str3="Python Programming"
slicedz=str3[:3]
print(slicedz)
# Out:
# Pyt

# %%
# *Write a code to convert the string "hello" to uppercaseP

str4="hello"
mmt=str4.upper()
print(mmt)
# Out:
# HELLO

# %%
# Write a code to replace the word "apple" with "orange" 
# in the string "I like apple"P

stringz="I like apple "
my2=stringz.replace("apple","orange")
my2
# Out:
# 'I like orange '

# %%
# Write a code to create a list with numbers 1 to 5 and print it
numberlis=list(range(0,5))
numberlis
# Out:
# [0, 1, 2, 3, 4]

# %%
# Write a code to append the number 10 to the list [1, 2, 3, 4]

thelist=[1,2,3,4,5]
thelist.append(10)
print(thelist)
# Out:
# [1, 2, 3, 4, 5, 10]

# %%
# Write a code to remove the number 3 from the list [1, 2, 3, 4, 5]
mylis=[1,2,3,4,5]
mylis.remove(3)
print(mylis)
# Out:
# [1, 2, 4, 5]

# %%
# Write a code to access the second element in the list ['a', 'b', 'c', 'd']
list=['a', 'b', 'c', 'd']
secondelemt=list[1]
print(secondelemt)
# Out:
# b

# %%
# questions : Write the functions takes the list as input
def onlynum(a):
    n=[]
    for i in a:
        if type(i)==int or type(i)==float:
            n.append(i)
    return n

# %%
onlynum([10,20,30,40,"muthu","money",70])
# Out:
# [10, 20, 30, 40, 70]
