# %%
A=3

# %%
A
# Out:
# 3

# %%
a="swamy love"
a
# Out:
# 'swamy love'

# %%
d=False
type(d)
# Out:
# bool

# %%
# assignment statements
# expression statements
a=10
b=15
a+b
# Out:
# 25

# %%
mylist=[1,2,3,4]
mylist[2]
# Out:
# 3

# %%
_mystr="hello"
_mystr[0]
# Out:
# 'h'

# %%
x=10
y=10
z=x+y

# %%
z
# Out:
# 20

# %%
int(x)
# Out:
# 10

# %%
type(x)
# Out:
# int

# %%
float(y)
# Out:
# 10.0

# %%
type(y)
# Out:
# int

# %%
age=30
if age > 15:
    print("adult")
else:
    print("Swamy")
# Out:
# adult

# %%
muthu=100
if 15>=muthu:
    print("great")
else:
    print("sammy")
# Out:
# sammy

# %%
marks =50
if marks > 75:
    print("you are topper")
elif marks==50:
    print("you passed")
else:
    print("you failed")
# Out:
# you passed

# %%
x=100
if x > 50:
    if x%2==0:
        print("positive")
    else:
        print("Negative")
# Out:
# positive
