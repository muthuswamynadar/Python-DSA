# %%
class car:
    def accelerate(self):
        print("car is accelerating")
    
    def breakx(self):
        print("Car is stopping")

    def deposit(self):
        print("Everything is comming")

# %%
c1=car()
c1.accelerate()
c1.breakx()
c1.deposit()
# Out:
# car is accelerating
# Car is stopping
# Everything is comming

# %%
class Bank:
    def deposits(self):
        print("I am depositing the money")
    def withdraw(self):
        print("withdraw the money")

# %%
c1=Bank()
c1.deposits()
c1.withdraw()
# Out:
# I am depositing the money
# withdraw the money

# %%
#  Extract the odd & even

# %%
class listops:
    l=[1,2,3,4,5,6,7]

    def extract_even(self,l):
        l1=[]
        for i in l:
            if i%2==0:
                l.append(i)
        return l

# %%
class maskoff:
    l=[1,22,3,65,30,14,6,7]
    
    def extract_even(self,l):
        la=[]
        for i in l:
            if i%2==0:
                la.append(i)
        return l

# %%
am=maskoff()
am.extract_even(l=[1,2,3,3,4,5,55,11,8,13],)
# Out:
# [1, 2, 3, 3, 4, 5, 55, 11, 8, 13]

# %%
class listops:
    def __init__(self,l):
        self.l=l
    def extract_even(self):
        l=self.l
        l1=[]
        for i in self.l:
            if i%2 ==0:
                l1.append(i)
        return l1

# %%
class listops:
    def __init__(self, l):
        self.l = l

    def extract_even(self):
        l1 = []
        for i in self.l:
            if i % 2 == 0:
                l1.append(i)
        return l1

# %% [markdown]
# # ChatGPT
