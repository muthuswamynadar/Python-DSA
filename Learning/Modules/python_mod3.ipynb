# %%
t=()

# %%
type(t)
# Out:
# tuple

# %%
t=("swamy",1,2,3,"muthu")
t
# Out:
# Running cells with 'venv (Python 3.13.2)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'f:/Python/venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
t[0]
# Out:
# 'swamy'

# %%
t.count("muthu")
# Out:
# 1

# %%
t1=(1,2,3,100,200,400,600,700)
max(t1)
# Out:
# 700

# %%
min(t1)
# Out:
# 1

# %%
len(t1)
# Out:
# 8

# %%
s={1,2,3,4,100,200,250,300,600}

# %%
type(s)
# Out:
# set

# %%
s
# Out:
# {2, 4, 100, 200, 250, 300, 600, 1200}

# %%
s. add(1200)

# %%
s.pop()
# Out:
# 1

# %%
s.remove(3)
