# %%
print('\n -- list methods ')
# Out:
#  -- list methods

# %%
mylist=[1,2,3]
mylist.append(4)

# %%
mylist
# Out:
# [1, 2, 3, 4]

# %%
mylist.append(24)

# %%
print(mylist)
# Out:
# [1, 2, 3, 4, 24]

# %%
mylist.remove(24)
print(mylist)
# Out:
# [1, 2, 3, 4]

# %%
mylist.insert(0,20)
print(mylist)
# Out:
# [20, 1, 2, 20, 3, 4]

# %%
print(mylist.pop())
# Out:
# 20

# %%
print(mylist)
# Out:
# [20, 1, 2]

# %%
mylist.remove(1)

# %%
print(mylist)
# Out:
# [2, 20]

# %%
mylist.reverse()

# %%
mylist.clear()

# %%
print(mylist)
# Out:
# []

# %% [markdown]
# # The Tupe begins

# %%
print('\n Tuple methods ')
# Out:
#  Tuple methods

# %%
mytuple=(1,2,3,4,5,6,7,7)
print('count(2)')

# %%
my_tuple = (1, 2, 3, 4, 5)
print(max(my_tuple))  # Output: 1
# Out:
# 5

# %%
print(sum(my_tuple))
# Out:
# 15

# %% [markdown]
# # String functions

# %%
print("\n--- STRING METHODS ---")
my_str = "  Hello World  "
print("lower:", my_str.lower())
print("upper:", my_str.upper())
print("strip:", my_str.strip())
print("lstrip:", my_str.lstrip())
print("rstrip:", my_str.rstrip())
# Out:
# --- STRING METHODS ---
# lower:   hello world
# upper:   HELLO WORLD
# strip: Hello World
# lstrip: Hello World
# rstrip:   Hello World
