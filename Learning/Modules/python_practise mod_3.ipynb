# %%
print('\n -- list methods ')
# Out:
#  -- list methods

# %%
mylist=[1,2,3]
mylist.append(4)

# %%
mylist
# Out:
# [1, 2, 3, 4]

# %%
mylist.append(24)

# %%
print(mylist)
# Out:
# [1, 2, 3, 4, 24]

# %%
mylist.remove(24)
print(mylist)
# Out:
# [1, 2, 3, 4]

# %%
mylist.insert(0,20)
print(mylist)
# Out:
# [20, 1, 2, 20, 3, 4]

# %%
print(mylist.pop())
# Out:
# 20

# %%
print(mylist)
# Out:
# [20, 1, 2]

# %%
mylist.remove(1)

# %%
print(mylist)
# Out:
# [20, 2]
